# %%
# Define IAM role
import boto3
import re
from sagemaker import get_execution_role

role = get_execution_role()

# %%
import numpy as np
import sagemaker.amazon.common as smac
import json
import sagemaker
import io
import os
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker.predictor import csv_serializer, json_deserializer

# %%
# Import the data
data = np.load('tsla_model_2_record.npy')
fourth_quarter = int(len(data) * 0.75)
train_data = data[:fourth_quarter]
test_data = data[fourth_quarter:]
ctrl_train_data = data[:fourth_quarter, 4:]
ctrl_test_data = data[fourth_quarter:, 4:]
only_twitter_train_data = np.delete(data[:fourth_quarter], 4, 1)
only_twitter_test_data = np.delete(data[fourth_quarter:], 4, 1)

# %%
# Here is what our training data looks like
print(data)
# Out:
# [[ 2.2000000e+01  5.0000000e+00  4.4000000e+01  2.0000000e+00
#    5.6642392e-03 -1.5619084e-03]
#  [ 2.8000000e+01  8.0000000e+00  2.2000000e+01  5.0000000e+00
#   -1.5619084e-03 -1.5880540e-03]
#  [ 3.9000000e+01  1.1000000e+01  2.8000000e+01  8.0000000e+00
#   -1.5880540e-03 -1.8778339e-02]
#  ...
#  [ 1.7100000e+02  5.5000000e+01  2.1000000e+02  7.4000000e+01
#   -1.9030344e-02  3.8025755e-02]
#  [ 1.1000000e+02  4.9000000e+01  1.7100000e+02  5.5000000e+01
#    3.8025755e-02 -6.7694499e-03]
#  [ 1.6200000e+02  3.7000000e+01  1.1000000e+02  4.9000000e+01
#   -6.7694499e-03 -3.0882113e-02]]

# %%
locations = uploadToBucket(ctrl_train_data, "tsla_model_2_ctrl") # choose control data or train data
linear = train(locations, 1) # 5 features for normal test, 1 for control
#linear = "linear-learner-2018-09-06-00-06-35-174"
exportResults(linear, ctrl_test_data, "tsla_model_2_ctrl_predictions")
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2018-09-12-18-28-54-095
# Uploaded training data location: s3://sagemaker-twitter-project/sagemaker/tsla_model_2_ctrl/train/linearlearner
# Training artifacts will be uploaded to: s3://sagemaker-twitter-project/sagemaker/tsla_model_2_ctrl/output
# .....................
# Docker entrypoint called with argument(s): train
# [09/12/2018 18:32:13 INFO 140071137314624] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [09/12/2018 18:32:13 INFO 140071137314624] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'1', u'mini_batch_size': u'5', u'predictor_type': u'regressor'}
# [09/12/2018 18:32:13 INFO 140071137314624] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'1', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'5', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'predictor_type': u'regressor', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [09/12/2018 18:32:13 WARNING 140071137314624] Loggers have already been setup.
# [09/12/2018 18:32:13 INFO 140071137314624] Using default worker.
# [09/12/2018 18:32:13 INFO 140071137314624] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [09/12/2018 18:32:13 INFO 140071137314624] Create Store: local
# [09/12/2018 18:32:13 INFO 140071137314624] Scaler algorithm parameters
#  {'data_sum':
# [ 0.16289456]
# <NDArray 1 @cpu(0)>, 'stdev_weight': True, 'data_sq_sum':
# [ 0.15068677]
# <NDArray 1 @cpu(0)>, 'label_sq_sum':
# [ 0.12917969]
# <NDArray 1 @cpu(0)>, 'data_points': 245L, 'stdev_label': True, 'label_sum':
# [ 0.03726103]
# <NDArray 1 @cpu(0)>, 'mean_label': True, 'mean_weight': True}
# [09/12/2018 18:32:13 INFO 140071137314624] Scaling model computed with parameters:
#  {'stdev_weight':
# [ 0.02479125]
# <NDArray 1 @cpu(0)>, 'stdev_label':
# [ 0.02296173]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [ 0.00015209]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [

#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1559946013956655, "sum": 1.1559946013956655, "min": 1.1559946013956655}}, "EndTime": 1536777136.133463, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1536777136.133447}
#
# [09/12/2018 18:32:16 INFO 140071137314624] #quality_metric: host=algo-1, epoch=2, train mse_objective <loss>=1.00935088189
# [09/12/2018 18:32:16 INFO 140071137314624] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=mse_objective, value=1.00912186509
# [09/12/2018 18:32:16 INFO 140071137314624] Epoch 2: Loss improved. Updating best model
# [09/12/2018 18:32:16 INFO 140071137314624] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 50, "sum": 50.0, "min": 50}, "Number of Batches Since Last Reset": {"count": 1, "max": 50, "sum": 50.0, "min": 50}, "Number of Records Since Last Reset": {"count": 1, "max": 248, "sum": 248.0, "min": 248}, "Total Batches Seen": {"count": 1, "max": 201, "sum": 201.0, "min": 201}, "Total Records Seen": {"count": 1, "max": 997, "sum": 997.0, "min": 997}, "Max Records Seen Between Resets": {"count": 1, "max": 248, "sum": 248.0, "min": 248}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1536777136.135618, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1536777135.264692}
#
# [09/12/2018 18:32:16 INFO 140071137314624] #throughput_metric: host=algo-1, train throughput=284.718098294 records/second
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.008065297530622, "sum": 1.008065297530622, "min": 1.008065297530622}}, "EndTime": 1536777136.988749, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.988679}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0105657952780627, "sum": 1.0105657952780627, "min": 1.0105657952780627}}, "EndTime": 1536777136.988844, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.988824}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0080698748632353, "sum": 1.0080698748632353, "min": 1.0080698748632353}}, "EndTime": 1536777136.988909, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.988894}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0105800125671893, "sum": 1.0105800125671893, "min": 1.0105800125671893}}, "EndTime": 1536777136.988969, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.988955}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1661004436259368, "sum": 1.1661004436259368, "min": 1.1661004436259368}}, "EndTime": 1536777136.989023, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989012}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1281666696071624, "sum": 1.1281666696071624, "min": 1.1281666696071624}}, "EndTime": 1536777136.989077, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989065}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1660566593919481, "sum": 1.1660566593919481, "min": 1.1660566593919481}}, "EndTime": 1536777136.989123, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989109}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.12820622464832, "sum": 1.12820622464832, "min": 1.12820622464832}}, "EndTime": 1536777136.9892, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989185}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0081038185528346, "sum": 1.0081038185528346, "min": 1.0081038185528346}}, "EndTime": 1536777136.989255, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989241}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0105535873344966, "sum": 1.0105535873344966, "min": 1.0105535873344966}}, "EndTime": 1536777136.989307, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989293}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0081198560948275, "sum": 1.0081198560948275, "min": 1.0081198560948275}}, "EndTime": 1536777136.989371, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989354}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0107261592028092, "sum": 1.0107261592028092, "min": 1.0107261592028092}}, "EndTime": 1536777136.989419, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989409}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1661716086523874, "sum": 1.1661716086523874, "min": 1.1661716086523874}}, "EndTime": 1536777136.989454, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989445}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1281767344596434, "sum": 1.1281767344596434, "min": 1.1281767344596434}}, "EndTime": 1536777136.9895, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989486}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.16621450599359, "sum": 1.16621450599359, "min": 1.16621450599359}}, "EndTime": 1536777136.989554, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989539}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.127922107857101, "sum": 1.127922107857101, "min": 1.127922107857101}}, "EndTime": 1536777136.989606, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989592}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.009716961578447, "sum": 1.009716961578447, "min": 1.009716961578447}}, "EndTime": 1536777136.989661, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989646}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0120937138795854, "sum": 1.0120937138795854, "min": 1.0120937138795854}}, "EndTime": 1536777136.989715, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989699}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.00972540062301, "sum": 1.00972540062301, "min": 1.00972540062301}}, "EndTime": 1536777136.989773, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989757}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0121280363627843, "sum": 1.0121280363627843, "min": 1.0121280363627843}}, "EndTime": 1536777136.989829, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989819}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1880409727291186, "sum": 1.1880409727291186, "min": 1.1880409727291186}}, "EndTime": 1536777136.989865, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989857}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.14087227382222, "sum": 1.14087227382222, "min": 1.14087227382222}}, "EndTime": 1536777136.9899, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989891}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.187085331702719, "sum": 1.187085331702719, "min": 1.187085331702719}}, "EndTime": 1536777136.989954, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.98994}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1434232280874739, "sum": 1.1434232280874739, "min": 1.1434232280874739}}, "EndTime": 1536777136.990008, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.989993}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0139307074400843, "sum": 1.0139307074400843, "min": 1.0139307074400843}}, "EndTime": 1536777136.990063, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1536777136.990048}
#
# ...
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1378446211012043, "sum": 1.1378446211012043, "min": 1.1378446211012043}}, "EndTime": 1536777139.733602, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 6}, "StartTime": 1536777139.733595}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1752988887684686, "sum": 1.1752988887684686, "min": 1.1752988887684686}}, "EndTime": 1536777139.733628, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 6}, "StartTime": 1536777139.733621}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1402440053467848, "sum": 1.1402440053467848, "min": 1.1402440053467848}}, "EndTime": 1536777139.733674, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 6}, "StartTime": 1536777139.73366}
#
# [09/12/2018 18:32:19 INFO 140071137314624] #quality_metric: host=algo-1, epoch=6, train mse_objective <loss>=1.00575246215
# [09/12/2018 18:32:19 INFO 140071137314624] #early_stopping_criteria_metric: host=algo-1, epoch=6, criteria=mse_objective, value=1.00569768524
# [09/12/2018 18:32:19 INFO 140071137314624] #progress_metric: host=algo-1, completed 46 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 50, "sum": 50.0, "min": 50}, "Number of Batches Since Last Reset": {"count": 1, "max": 50, "sum": 50.0, "min": 50}, "Number of Records Since Last Reset": {"count": 1, "max": 248, "sum": 248.0, "min": 248}, "Total Batches Seen": {"count": 1, "max": 401, "sum": 401.0, "min": 401}, "Total Records Seen": {"count": 1, "max": 1989, "sum": 1989.0, "min": 1989}, "Max Records Seen Between Resets": {"count": 1, "max": 248, "sum": 248.0, "min": 248}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1536777139.734413, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 6}, "StartTime": 1536777138.874939}
#
# [09/12/2018 18:32:19 INFO 140071137314624] #throughput_metric: host=algo-1, train throughput=288.501858422 records/second
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0050567316157477, "sum": 1.0050567316157477, "min": 1.0050567316157477}}, "EndTime": 1536777140.539032, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.538938}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0104740094773623, "sum": 1.0104740094773623, "min": 1.0104740094773623}}, "EndTime": 1536777140.539137, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539121}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0050814199812559, "sum": 1.0050814199812559, "min": 1.0050814199812559}}, "EndTime": 1536777140.539178, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539169}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0104813693737498, "sum": 1.0104813693737498, "min": 1.0104813693737498}}, "EndTime": 1536777140.539209, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539202}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.158000520114996, "sum": 1.158000520114996, "min": 1.158000520114996}}, "EndTime": 1536777140.539246, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539236}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.120384438123022, "sum": 1.120384438123022, "min": 1.120384438123022}}, "EndTime": 1536777140.539296, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539286}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1580244447807877, "sum": 1.1580244447807877, "min": 1.1580244447807877}}, "EndTime": 1536777140.539331, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539323}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1203990565879005, "sum": 1.1203990565879005, "min": 1.1203990565879005}}, "EndTime": 1536777140.539368, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539355}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0050083005306671, "sum": 1.0050083005306671, "min": 1.0050083005306671}}, "EndTime": 1536777140.539406, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539397}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0104531898182265, "sum": 1.0104531898182265, "min": 1.0104531898182265}}, "EndTime": 1536777140.539433, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539426}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0051251603632556, "sum": 1.0051251603632556, "min": 1.0051251603632556}}, "EndTime": 1536777140.539459, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539452}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0105319890440727, "sum": 1.0105319890440727, "min": 1.0105319890440727}}, "EndTime": 1536777140.539486, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.53948}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1579162284123654, "sum": 1.1579162284123654, "min": 1.1579162284123654}}, "EndTime": 1536777140.539513, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539506}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1203362020302792, "sum": 1.1203362020302792, "min": 1.1203362020302792}}, "EndTime": 1536777140.53954, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539533}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1578929698893001, "sum": 1.1578929698893001, "min": 1.1578929698893001}}, "EndTime": 1536777140.539566, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539559}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1202450984594774, "sum": 1.1202450984594774, "min": 1.1202450984594774}}, "EndTime": 1536777140.539592, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539586}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0066548542100555, "sum": 1.0066548542100555, "min": 1.0066548542100555}}, "EndTime": 1536777140.539618, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539612}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0117816354547229, "sum": 1.0117816354547229, "min": 1.0117816354547229}}, "EndTime": 1536777140.539645, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539638}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0066594171280763, "sum": 1.0066594171280763, "min": 1.0066594171280763}}, "EndTime": 1536777140.539688, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539675}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0117974507565402, "sum": 1.0117974507565402, "min": 1.0117974507565402}}, "EndTime": 1536777140.539744, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539729}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1574829388637933, "sum": 1.1574829388637933, "min": 1.1574829388637933}}, "EndTime": 1536777140.539793, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539783}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1328257340557721, "sum": 1.1328257340557721, "min": 1.1328257340557721}}, "EndTime": 1536777140.539836, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539825}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.158168323064337, "sum": 1.158168323064337, "min": 1.158168323064337}}, "EndTime": 1536777140.539866, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539859}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1342984114070327, "sum": 1.1342984114070327, "min": 1.1342984114070327}}, "EndTime": 1536777140.539893, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539886}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0112584487516052, "sum": 1.0112584487516052, "min": 1.0112584487516052}}, "EndTime": 1536777140.539919, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539912}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0158754849312257, "sum": 1.0158754849312257, "min": 1.0158754849312257}}, "EndTime": 1536777140.539945, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539938}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.01121529054885, "sum": 1.01121529054885, "min": 1.01121529054885}}, "EndTime": 1536777140.539971, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.539964}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.015861355041971, "sum": 1.015861355041971, "min": 1.015861355041971}}, "EndTime": 1536777140.539997, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.53999}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1567815342727972, "sum": 1.1567815342727972, "min": 1.1567815342727972}}, "EndTime": 1536777140.540023, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.540016}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1382321802937254, "sum": 1.1382321802937254, "min": 1.1382321802937254}}, "EndTime": 1536777140.540049, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.540042}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1557462282326756, "sum": 1.1557462282326756, "min": 1.1557462282326756}}, "EndTime": 1536777140.540074, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.540068}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1405377401381123, "sum": 1.1405377401381123, "min": 1.1405377401381123}}, "EndTime": 1536777140.5401, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777140.540094}
#
# [09/12/2018 18:32:20 INFO 140071137314624] #quality_metric: host=algo-1, epoch=7, train mse_objective <loss>=1.00505673162
# [09/12/2018 18:32:20 INFO 140071137314624] #early_stopping_criteria_metric: host=algo-1, epoch=7, criteria=mse_objective, value=1.00500830053
# [09/12/2018 18:32:20 INFO 140071137314624] Early stop condition met. Stopping training.
# [09/12/2018 18:32:20 INFO 140071137314624] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 50, "sum": 50.0, "min": 50}, "Number of Batches Since Last Reset": {"count": 1, "max": 50, "sum": 50.0, "min": 50}, "Number of Records Since Last Reset": {"count": 1, "max": 248, "sum": 248.0, "min": 248}, "Total Batches Seen": {"count": 1, "max": 451, "sum": 451.0, "min": 451}, "Total Records Seen": {"count": 1, "max": 2237, "sum": 2237.0, "min": 2237}, "Max Records Seen Between Resets": {"count": 1, "max": 248, "sum": 248.0, "min": 248}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1536777140.540931, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1536777139.734716}
#
# [09/12/2018 18:32:20 INFO 140071137314624] #throughput_metric: host=algo-1, train throughput=307.563756829 records/second
# [09/12/2018 18:32:20 WARNING 140071137314624] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/12/2018 18:32:20 WARNING 140071137314624] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/12/2018 18:32:20 INFO 140071137314624] #train_score (algo-1) : ('mse_objective', 0.00052130054630270613)
# [09/12/2018 18:32:20 INFO 140071137314624] #quality_metric: host=algo-1, train mse_objective <loss>=0.000521300546303
# [09/12/2018 18:32:20 INFO 140071137314624] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 1e-05}
# [09/12/2018 18:32:20 INFO 140071137314624] Saved checkpoint to "/tmp/tmpfrFNdf/mx-mod-0000.params"
# [09/12/2018 18:32:20 INFO 140071137314624] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 7428.668022155762, "sum": 7428.668022155762, "min": 7428.668022155762}, "finalize.time": {"count": 1, "max": 36.34214401245117, "sum": 36.34214401245117, "min": 36.34214401245117}, "initialize.time": {"count": 1, "max": 191.04599952697754, "sum": 191.04599952697754, "min": 191.04599952697754}, "check_early_stopping.time": {"count": 8, "max": 1.338958740234375, "sum": 4.707574844360352, "min": 0.1418590545654297}, "setuptime": {"count": 1, "max": 16.602039337158203, "sum": 16.602039337158203, "min": 16.602039337158203}, "update.time": {"count": 8, "max": 992.9249286651611, "sum": 7092.6148891448975, "min": 806.0050010681152}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1536777140.585302, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1536777133.24088}
# INFO:sagemaker:Creating model with name: linear-learner-2018-09-12-18-33-06-104
# Billable seconds: 119
# INFO:sagemaker:Creating endpoint with name linear-learner-2018-09-12-18-28-54-095
# --------------------------------------------------------------------------------------!
# INFO:sagemaker:Deleting endpoint with name: linear-learner-2018-09-12-18-28-54-095

# %%
# Upload training data to S3 bucket and return the location to which training artificats will be uploaded
def uploadToBucket(data, name):
    bucket = "sagemaker-twitter-project"
    prefix = "sagemaker/" + name
    labels = data[:, -1]
    train = data[:, :-1]
    
    buf = io.BytesIO()
    smac.write_numpy_to_dense_tensor(buf, train, labels)
    buf.seek(0)

    key = 'linearlearner'
    boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buf)

    s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)
    print('Uploaded training data location: {}'.format(s3_train_data))

    output_location = 's3://{}/{}/output'.format(bucket, prefix)
    print('Training artifacts will be uploaded to: {}'.format(output_location))
    
    return [output_location, s3_train_data]

# %%
# Specify model image, initialize estimator, and train our model
def train(output_location, num_features):
    sess = sagemaker.Session()
    container = get_image_uri(boto3.Session().region_name, 'linear-learner')
    
    linear = sagemaker.estimator.Estimator(container,
                                           role = role, 
                                           train_instance_count = 1, 
                                           train_instance_type = 'ml.m4.xlarge',
                                           output_path = locations[0],
                                           sagemaker_session = sess)

    linear.set_hyperparameters(feature_dim = num_features, mini_batch_size = 5, predictor_type = 'regressor')

    linear.fit({'train': locations[1]})
    
    return linear

# %%
# Compile prediction results
def exportResults(linear, test_data, name):
    # Load the test data and deploy an endpoint
    if isinstance(linear, str):
        estimator = sagemaker.estimator.Estimator.attach(linear)
        predictor = estimator.deploy(initial_instance_count = 1, instance_type='ml.t2.medium')
    else:
        predictor = linear.deploy(initial_instance_count = 1, instance_type='ml.t2.medium')

    predictor.content_type = 'text/csv'
    predictor.serializer = csv_serializer
    predictor.deserializer = json_deserializer

    predictions = []
    for datum in test_data:
        result = predictor.predict(datum[:-1])
        predictions.append([result['predictions'][0]['score'], datum[-1]])
    
    # Delete endpoint
    sagemaker.Session().delete_endpoint(predictor.endpoint)
    
    # Save record of model predictions for offline analysis
    np.save(name + '.npy', predictions)
